# %%
# Type Casting

# %%
a = int('12')
b = 23
print(a+b)
# Out:
# 35

# %%
s = '34.6'
int(float(s))
# Out:
# 34

# %%
s = 'ayush'
int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 s = 'ayush'
# ----> 2 int(s)
#
# ValueError: invalid literal for int() with base 10: 'ayush'

# %%
s
# Out:
# 'ayush'

# %%
list(s)
# Out:
# ['a', 'y', 'u', 's', 'h']

# %%
a = input('Enter name  1: ')
b = input('Enter name 2: ')

print(a+b)
# Out:
# Enter name  1:  ayush
# Enter name 2:  drishti
# ayushdrishti

# %%
a = 23
a = str(a)

print(a,type(a))
# Out:
# 23 <class 'str'>

# %%
var = 'Kartik'
min(var)
# Out:
# 'K'

# %%
chr(2361)
# Out:
# 'ह'

# %%
for i in range(128540,128600):
    print(chr(i),end='')
# Out:
# 😜😝😞😟😠😡😢😣😤😥😦😧😨😩😪😫😬😭😮😯😰😱😲😳😴😵😶😷😸😹😺😻😼😽😾😿🙀🙁🙂🙃🙄🙅🙆🙇🙈🙉🙊🙋🙌🙍🙎🙏🙐🙑🙒🙓🙔🙕🙖🙗

# %%
#min and max
a = [122,232,3232,23]
min(a)
# Out:
# 23

# %%
max(a)
# Out:
# 3232

# %%
sum(a)
# Out:
# 3609

# %%
len(a)
# Out:
# 4

# %%
list(reversed(a))
# Out:
# [23, 3232, 232, 122]

# %%
sorted(a)
# Out:
# [23, 122, 232, 3232]

# %%
list(reversed(sorted(a)))
# Out:
# [3232, 232, 122, 23]

# %%
# eval()
eval('print(12-23+34)')
# Out:
# 23

# %%
name = 'ayush'
a= eval(input('Enter something: '))

print(a,type(a))
# Out:
# Enter something:  print(name)
# ayush
# None <class 'NoneType'>

# %%
#exec()
exec('sec = "B";Age=23')

# %%
print(Age)
# Out:
# 23

# %%
print(sec)
# Out:
# B

# %%
exec('a = 12; b = 23; c = a+b; print(c,type(c))')
# Out:
# 35 <class 'int'>

# %%
execfile('marker.py')
# Out:
# Welcome to ayush
# Enter your Name:  Drishti
# Hello Drishti How are you??
# -----------------------------------------------
# 😜😝😞😟😠😡😢😣😤😥😦😧😨😩😪😫😬😭😮😯😰😱😲😳😴😵😶😷😸😹😺😻😼😽😾😿🙀🙁🙂🙃🙄🙅🙆🙇🙈🙉🙊🙋🙌🙍🙎🙏🙐🙑🙒🙓🙔🙕🙖🙗
