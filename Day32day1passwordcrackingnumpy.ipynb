# %%
user = 'Ayush Drishti'.upper()
for i in user:
    if i ==' ':
        print(i,end='')

    else:
         print(chr((ord(i)-65)+120016),end='')
# Out:
# 𝓐𝓨𝓤𝓢𝓗 𝓓𝓡𝓘𝓢𝓗𝓣𝓘

# %%
def change_font(data):
    for i in data.upper():
        if i ==' ':
           print(i,end='')

        else:
          print(chr((ord(i)-65)+120016),end='')

# %%
change_font('i am ayush')
# Out:
# 𝓘 𝓐𝓜 𝓐𝓨𝓤𝓢𝓗

# %%
import numpy as np
combi = 'ajhgy'
cou = 1


for i,j in np.ndenumerate(np.random.randint(1,10(len(combi),)*len(combi))):
    if len(set(i)) == len(combi):
        print(i)
        cou+=1
# Out:
# (0, 1, 2, 3, 4)
# (0, 1, 2, 4, 3)
# (0, 1, 3, 2, 4)
# (0, 1, 3, 4, 2)
# (0, 1, 4, 2, 3)
# (0, 1, 4, 3, 2)
# (0, 2, 1, 3, 4)
# (0, 2, 1, 4, 3)
# (0, 2, 3, 1, 4)
# (0, 2, 3, 4, 1)
# (0, 2, 4, 1, 3)
# (0, 2, 4, 3, 1)
# (0, 3, 1, 2, 4)
# (0, 3, 1, 4, 2)
# (0, 3, 2, 1, 4)
# (0, 3, 2, 4, 1)
# (0, 3, 4, 1, 2)
# (0, 3, 4, 2, 1)
# (0, 4, 1, 2, 3)
# (0, 4, 1, 3, 2)
# (0, 4, 2, 1, 3)
# (0, 4, 2, 3, 1)
# (0, 4, 3, 1, 2)
# (0, 4, 3, 2, 1)
# (1, 0, 2, 3, 4)
# (1, 0, 2, 4, 3)
# (1, 0, 3, 2, 4)
# (1, 0, 3, 4, 2)
# (1, 0, 4, 2, 3)
# (1, 0, 4, 3, 2)
# (1, 2, 0, 3, 4)
# (1, 2, 0, 4, 3)
# (1, 2, 3, 0, 4)
# (1, 2, 3, 4, 0)
# (1, 2, 4, 0, 3)
# (1, 2, 4, 3, 0)
# (1, 3, 0, 2, 4)
# (1, 3, 0, 4, 2)
# (1, 3, 2, 0, 4)
# (1, 3, 2, 4, 0)
# (1, 3, 4, 0, 2)
# (1, 3, 4, 2, 0)
# (1, 4, 0, 2, 3)
# (1, 4, 0, 3, 2)
# (1, 4, 2, 0, 3)
# (1, 4, 2, 3, 0)
# (1, 4, 3, 0, 2)
# (1, 4, 3, 2, 0)
# (2, 0, 1, 3, 4)
# (2, 0, 1, 4, 3)
# (2, 0, 3, 1, 4)
# (2, 0, 3, 4, 1)
# (2, 0, 4, 1, 3)
# (2, 0, 4, 3, 1)
# (2, 1, 0, 3, 4)
# ...

# %%
import numpy as np
pwd = 'ayush'

combi = ['y','u','s','h','a']

cou =1
for i,j in np.ndenumerate(np.random.randint(1,10,(len(combi),)*len(combi))):
    if len(set(i)) == len(combi):
        for num in i:
            print(combi[num],end = '')
        cou+=1
        print()
# Out:
# yusha
# yusah
# yuhsa
# yuhas
# yuash
# yuahs
# ysuha
# ysuah
# yshua
# yshau
# ysauh
# ysahu
# yhusa
# yhuas
# yhsua
# yhsau
# yhaus
# yhasu
# yaush
# yauhs
# yasuh
# yashu
# yahus
# yahsu
# uysha
# uysah
# uyhsa
# uyhas
# uyash
# uyahs
# usyha
# usyah
# ushya
# ushay
# usayh
# usahy
# uhysa
# uhyas
# uhsya
# uhsay
# uhays
# uhasy
# uaysh
# uayhs
# uasyh
# uashy
# uahys
# uahsy
# syuha
# syuah
# syhua
# syhau
# syauh
# syahu
# suyha
# suyah
# suhya
# suhay
# suayh
# suahy
# shyua
# shyau
# shuya
# shuay
# shayu
# shauy
# sayuh
# sayhu
# sauyh
# sauhy
# sahyu
# sahuy
# hyusa
# hyuas
# hysua
# hysau
# hyaus
# hyasu
# huysa
# huyas
# husya
# husay
# huays
# huasy
# hsyua
# hsyau
# hsuya
# hsuay
# hsayu
# hsauy
# hayus
# haysu
# hauys
# hausy
# hasyu
# hasuy
# ayush
# ayuhs
# aysuh
# ayshu
# ayhus
# ayhsu
# auysh
# auyhs
# ausyh
# aushy
# auhys
# auhsy
# asyuh
# asyhu
# asuyh
# asuhy
# ashyu
# ashuy
# ahyus
# ahysu
# ahuys
# ahusy
# ahsyu
# ahsuy

# %%
## password crack
pwd = 'ayush@12'
combi = list(pwd)
cou =1
for i,j in np.ndenumerate(np.random.randint(1,10,(len(combi),)*len(combi))):
    if len(set(i)) == len(combi):
        temp_pwd =''
        for num in i:
   #         print(combi[num],end = '')
            temp_pwd += combi[num]
        #print(temp_pwd)
        if temp_pwd == pwd:
            print('password cracked',temp_pwd)
            break

        else:
            print(f'trying!! attempts: {cou}')
            display(clear = True)
        temp_pwd = ''
        cou+=1
# Out:
# password cracked ayush@12
