# %%
import string
import random


all_str = string.ascii_letters+string.digits+string.punctuation

pwd = ''

pwd_len = 12
for i in range(pwd_len):
    pwd += random.choice(all_str)

print('your password: ',pwd)
# Out:
# your password:  m>Q5h!{$n4]9

# %% [markdown]
# # function

# %%
def greet():
    print('Hello Buddy!!')

# %%
for i in range(10):
    greet()
# Out:
# Hello Buddy!!
# Hello Buddy!!
# Hello Buddy!!
# Hello Buddy!!
# Hello Buddy!!
# Hello Buddy!!
# Hello Buddy!!
# Hello Buddy!!
# Hello Buddy!!
# Hello Buddy!!

# %%
def ayush():
    print('Love Drishti')

# %%
ayush()
# Out:
# Love Drishti

# %%
 def greet():
     name = input('Enter your name')
     print(f'Hello {name}\ntere mkc')

# %%
greet()
# Out:
# Enter your name sad
# Hello sad
# tere mkc

# %%
def greet(name):
    print(f'Hello {name}\nhow are you')  #bnate wakt kuch likha bracket mai to woh parameter hai
                                         # use karte woh argument hai

# %%
greet('ayush')
# Out:
# Hello ayush
# how are you

# %%
def greet(name:str):
    if type(name) == str:
        
        print(f'Hello {name}\nhow are you') 
    else:
       print('invalid')

# %%
greet(12323)
# Out:
# invalid

# %%
greet('ayush')
# Out:
# Hello ayush
# how are you

# %%
def  add(x,y):
    print(x+y)

# %%
add(12,32)
# Out:
# 44

# %%
def sub(x,y):
    print(x-y)

# %%
sub(43,34)
# Out:
# 9

# %%
def students_details(name:'str',
                     age:'int',
                     sec:'str',
                     address:'kaisa bhi',
                     contact:'int',
                     roll: 'int'):
    print(f'your name is {name}')
    print(f'your age is {age}')
    print(f'your sec is {sec}')
    print(f'your address is {address}')
    print(f'your roll is {roll}')

# %%
#positional argument

# %%
students_details(sec='b',name='ayush',address='noida',roll=34,contact=9424306727,age=20)
# Out:
# your name is ayush
# your age is 20
# your sec is b
# your address is noida
# your roll is 34

# %%
# default parameter

# %%
def students_details(name, age,address,sec, contact,roll,fees = 'yes' ):
    print(f'your name is {name}')
    print(f'your age is {age}')
    print(f'your sec is {sec}')
    print(f'your address is {address}')
    print(f'your roll is {roll}')
    print(f'your fees is  {fees} ')

# %%
students_details(sec='b',name='ayush',address='noida',roll=34,contact=9424306727,age=20)
# Out:
# your name is ayush
# your age is 20
# your sec is b
# your address is noida
# your roll is 34
# your fees is  yes
