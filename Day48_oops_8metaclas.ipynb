# %%
number  = 45
for i in range(2,number):
    if number % i==0:
        print('NO Prime')
        break

else:
    print('')

print('prime')
# Out:
# NO Prime
# prime

# %% [markdown]
# # Nested Class

# %%
def one():
    print('one')
    def two():
        print('two')

# %%
class Employee:
    def __init__(self,dd,mm,yy):
        print('''Employee 2.6.1 (SDL 2.28.4, Python 3.12.7)
Hello from the pygame community. https://www.Employee.org/contribute.html
(5,0)''')
        print('Employee class init')
    class Employee_Trip:
        def __init__(self):
            print('employee trip init')
        def goa(self):
            print('gao trip!!')
        def haridwar(self):
            print('Nepal Trip')

    class DOB:
        def __init__(self,dd,mm,yy):
            print(f'your D.O.B is {dd}/{mm}/{yy}')
    def salary(self):
        print('Employee salary')
    def promotion(self):
        print('promo func')

# %%
emp = Employee(1,1,2024)
# Out:
# Employee 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.Employee.org/contribute.html
# (5,0)
# Employee class init

# %%
ayush = Employee()
# Out:
# Employee class init

# %%
ayush.DOB(12,12,2003)
# Out:
# your D.O.B is 12/12/2003

# %%
import pygame
pygame.init()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# (5, 0)

# %%
e1 = Employee()
# Out:
# Employee class init

# %%
trip = e1.Employee_Trip()
# Out:
# employee trip init

# %%
trip.goa()
# Out:
# gao trip!!

# %%
import pandas as pd

# %%
data = {'name':['ayush','ajay'],'sec':list('AB')}
table = pd.DataFrame(data)

# %%
# __deepcopy__ double underscore mai hai toh magic method kehte hai or jo capital mai hai use class kehte hai 'T'

# %%
print(dir(table))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__'
# ...

# %% [markdown]
# # Destructor

# %%
class Ayushvidya:
    def __init__(self):
        print('class constructor!!')

    def a(self):
        print('a')
    def  b(self):
        print('b')

    def __del__(self):
        print('class destructor called')

# %%
obj = Ayushvidya()
# Out:
# class constructor!!

# %%
id(obj)
# Out:
# 2493221741024

# %%
del obj
# Out:
# class destructor called

# %%
obj = Ayushvidya()
# Out:
# class constructor!!

# %%
id(obj)
# Out:
# 2493222192576

# %%
del obj
# Out:
# class destructor called

# %%
import gc

# %%
gc.collect()
# Out:
# 0

# %% [markdown]
# # meta class: with type function

# %%
type(obj)
# Out:
# __main__.Ayushvidya

# %%
# meta class
dr = type('Ayush',(object,),dict(salary=23987,Address = 'Noida'))

# %%
dr.mro()
# Out:
# [__main__.Ayush, object]

# %%
dr.Address
# Out:
# 'Noida'

# %%
f = dr()
