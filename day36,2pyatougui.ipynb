# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests as r

# %%
url = ''' https://cdn.britannica.com/11/271611-050-6CAD4D54/Indian-Cricketer-Sachin-Tendulkar-Raises-Bat-On-Scoring-Century-During-Group-B-ICC-World-Cup-Cricket-Match-Between-India-And-South-Africa-Nagpur-March-12-2011.jpg'''

response = r.get(url)

# %%
data = response.content

# %%
f = open(r"C:\Users\ASUS\OneDrive\Desktop\sachin.jpg",'wb')
f.write(data)
f.close()

print('done')
# Out:
# done

# %%
with open(r"C:\Users\ASUS\OneDrive\Desktop\sachin.jpg",'wb') as ayush :
    ayush.write(data)

print('done')
# Out:
# done

# %%
with open('day36binarydatahandling.ipynb','rb') as f:

   with open(r"C:\Users\ASUS\OneDrive\Desktop\file_handling.ipynb",'wb')as nf:

      nf.write(f.read())

print('done')
# Out:
# done

# %%
path = r"C:\Users\ASUS\OneDrive\Desktop\ayush"


for i in range(1,11):
    url = '''https://picsum.photos/200/300'''

    request = r.get(url)
    data = response.content
    with open(path+f'\\inst_images_{i}.jpg','wb') as f:
           f.write(data)


print('done')

# %%
)
