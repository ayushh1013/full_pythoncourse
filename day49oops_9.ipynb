# %% [markdown]
# # Module package

# %%
pip install pyttsx3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import random

import ayush_module as dris
print('don')
# Out:
# don

# %%
dris.random.randint(1,100)
# Out:
# 36

# %%
axis = dris.ATM()
# Out:
# Enter your pin:  0000
#
# Select any one choice:
# 1> Check Balance
# 2> Withdrawal
# 3> Deposit
# 4> Pin Change
# 5> Past Statements
# 6> Fast Cash
# >>  3
# Enter amount:  789
# Amount must be multiple of 100

# %%
import IPython as up

# %%
up.display.Code('ayush_module.py')
# Out:
# import random
# import time
# import re
# import pyttsx3
#
# engine = pyttsx3.init()
#
# def speak(text):
#     engine.say(text)
#     engine.runAndWait()
#
#
# class ATM:
#     def __init__(self):
#         self.balance = 2000000000
#         self.pin = '0000'
#
#         user_pin = input('Enter your pin: ')
#         if user_pin == self.pin:
#             user_choice = input('''
# Select any one choice:
# 1> Check Balance
# 2> Withdrawal
# 3> Deposit
# 4> Pin Change
# 5> Past Statements
# 6> Fast Cash
# >> ''')
#
#             if user_choice == '1':
#                 self.check_balance()
#             elif user_choice == '2':
#                 self.withdrawl()
#             elif user_choice == '3':
#                 self.user_deposit()
#             elif user_choice == '4':
#                 self.pin_change()
#             elif user_choice == '5':
#                 self.past_statements()
#             elif user_choice == '6':
#                 self.fast_cash()
#             else:
# ...

# %%
import os

# %%
os.sys.path
# Out:
# ['C:\\Users\\ASUS\\techvidya.py\\python_dafullcourse',
#  'C:\\ProgramData\\anaconda3\\python312.zip',
#  'C:\\ProgramData\\anaconda3\\DLLs',
#  'C:\\ProgramData\\anaconda3\\Lib',
#  'C:\\ProgramData\\anaconda3',
#  '',
#  'C:\\Users\\ASUS\\AppData\\Roaming\\Python\\Python312\\site-packages',
#  'C:\\ProgramData\\anaconda3\\Lib\\site-packages',
#  'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\win32',
#  'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\setuptools\\_vendor']

# %%
os.sys.path.append(r"C:\Users\ASUS\Downloads")

# %%
import ayush_module as drishti

# %%
hdfc = drishti.ATM()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 hdfc = drishti.ATM()
#
# NameError: name 'drishti' is not defined
