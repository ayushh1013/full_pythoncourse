# %%
pip install PyAutoGUI
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
pip install pygame
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
import pyautogui as py
import time

data = ' i am ayush'

for i in data :
     py.write(i)

# %%
 i am ayush
# Out:
#   Cell In[4], line 1
#     i am ayush
#       ^
# SyntaxError: invalid syntax

# %%
import pygame
from gtts import gTTS
pygame.init()
time.sleep(5)

data = '''ayush hamesha great rahega usko koi rok nhiskta kyuki ek  din mai world ka sabse bada or amir aadmi banega uke sath ek ladki hogi ds the great '''

speech = gTTS(data)
speech.save('temp.mp3')

sound = pygame.mixer.Sound('tech.mp3')
sound.play()

for i in data:
    py.write(i)

# %% [markdown]
# ## files

# %%
#Two types files :- Textual , Binary file

# %%
#those that can be open in and user can understand
## textual files :- notepad , csv,.py

#Binary :- those that can't be open in notepad and user can't understand

## Binary:- pdf, mp3,mp4,jpg,xlsx

# %%
file.close()
print('closed')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 file.close()
#       2 print('closed')
#
# NameError: name 'file' is not defined

# %%
f = open(r"C:\Users\ASUS\OneDrive\Desktop\Data analyst\ayush.py")

data =[]

for i  in f.readline():
    print(i.upper())
# Out:
# I
# M
# P
# O
# R
# T
#
# R
# A
# N
# D
# O
# M

# %%
f = open(r"C:\Users\ASUS\OneDrive\Desktop\Data analyst\ayush.py")

# %%
data = []
while True:
    temp_data = f.readline()
    if len(temp_data)>0:
      data.append(temp_data)
    else:
        break

# %%
print(data)
# Out:
# ['import random\n', 'print(random.randint(1,11))']

# %%
data[1]
# Out:
# 'print(random.randint(1,11))'

# %%
for i in data:
    print(i,end='')
# Out:
# import random
# print(random.randint(1,11))

# %%
f = open(r"C:\Users\ASUS\OneDrive\Desktop\Data analyst\ayush.py")
data = f.readlines()

# %%
f = open('ayush.txt',mode = 'w')

# %%
f.write('you are in jabalpur')
f.write('\nwe are learning python')

f.close()

# %%
f1 = open('ayush.txt',mode = 'r')
data = f1.read()
f2 = open('ayush_copy.txt', mode = 'w')

f2.write(data)
f1.close()
f2.close()

# %%
data = 'name,age,address,class,roll_no,data_time\n'.upper()

from datetime import datetime
for i in range(2):

    name = input('enter your name')
    
    age = input('enter your age')
    
    
    address = input('enter your address')
    
    classs = input('enter your class')

    roll_no = input('enter your roll_no')

    abhi = datetime.now()
    one_row = f'{name},{age},{address},{classs},{roll_no}'

    data += one_row+'\n'

    print(f'''{i+1} row data inserted successfully!!''', end='\n'*2)

f = open(r'C:\Users\ASUS\OneDrive\Desktop\ayush.txtt\student_details.csv','w')
f.write(data)
f.close()
print('done')
# Out:
# enter your name jhgf
# enter your age ';lkj
# enter your address lkjhg
