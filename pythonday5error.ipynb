# %%
a = 'ayush'
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 a = 'ayush'
# ----> 2 int(a)
#
# ValueError: invalid literal for int() with base 10: 'ayush'

# %%
a = 13
bool(a)
# Out:
# True

# %%
s = 0
bool(s)
# Out:
# False

# %%
d = None
bool(d)
# Out:
# False

# %%
b = 'gfhfh'
bool(b)
# Out:
# True

# %%
g = -87654
bool(g)
# Out:
# True

# %%
s = 89 - 7j

set(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 s = 89 - 7j
# ----> 3 set(s)
#
# TypeError: 'complex' object is not iterable

# %%
g = '[12,34,67,78]'
g
# Out:
# '[12,34,67,78]'

# %%
g = True
str(g)
# Out:
# 'True'

# %%
d = (('name',2345),)
dict(d)
# Out:
# {'name': 2345}

# %%
# how to write multiple statments in one line

# %%
a = 234;b = 'ayush';c = [232,8668,988,7];d = {1,243,6}
print(b)
# Out:
# ayush

# %%
# how to declare same values to diff variables

# %%
g,h,k,=56
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 g,h,k,=56
#
# TypeError: cannot unpack non-iterable int object

# %%
a = b =c=d=e=45
a
# Out:
# 45

# %%
# packing and unpacking concept

# %%
var = [1,2,3,4,5,6]

# %%
#a = [1,2,3,4,5]

# %%
#unpacking
a,b,c,d,e,f=[1,2,3,4,5,6]

# %%
f
# Out:
# 6

# %%
names = ['A','b','h','k']
s1,s2,s3,s4 = names

# %%
s2
# Out:
# 'b'

# %%
a,b,f=3,4,5

# %%
a
# Out:
# 3

# %%
a,b,c,d,e,f,g = 'Drishti'

# %%
b
# Out:
# 'r'

# %%
s1,s2,s3,s4 = names

# %%
students = s1,s2,s3,s4
students
# Out:
# ('A', 'b', 'h', 'k')

# %%
students = list((s1,s2,s3,s4))

# %%
students
# Out:
# ['A', 'b', 'h', 'k']

# %% [markdown]
# # STRING TOPIC

# %%
#m2
s = 'komal\'sHouse'
print(s,type(s))
# Out:
# komal'sHouse <class 'str'>

# %%
print('ayush the graet fhgfhfdfcfvjcdfyyyj')
# Out:
# ayush the graet fhgfhfdfcfvjcdfyyyj

# %%
# string:- as an index

# %%
a = 'Ayush'

# %%
a[2]+a[3]
# Out:
# 'us'

# %%
a
# Out:
# 'Ayush'
