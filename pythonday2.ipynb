# %%
# assignment operator

# %%
a = 23
print(a)
# Out:
# 23

# %%
a = 23 
a += 10
print(a)
# Out:
# 33

# %%
a = 10
a+=10
a+=20
a-=10
a*=10
a//=10
a**=2
print(a)
# Out:
# 900

# %%
# comparision op

# %%
#<
#>
#<=
#==
#!=

# %%
a = 34
b = 43

print(a>b)
# Out:
# False

# %%
a = 'ayush'
b = 'drishti'
print(a<b)
# Out:
# True

# %%
ord('a')
# Out:
# 97

# %%
ord('v')
# Out:
# 118

# %%
ord('d')
# Out:
# 100

# %%
# identity op
# is or is not

# %%
a = [1,243,65,8]
b = [1,243,65,8]
a= b
a is b
# Out:
# True

# %%
a= 10
b =10
#a = b
a is b
# Out:
# True

# %%
a = 'drishti'
b = 'drishti'
a is not b
#a is b
# Out:
# False

# %%
print(len(a))
# Out:
# 7

# %% [markdown]
# # membership operator
# # in , not in

# %%
a = [123,3,2,323,324,313]
123 in a
# Out:
# True

# %%
'd' in a
# Out:
# False

# %%
'd' not in a
# Out:
# True

# %%
# logical operator
#and , or ,not

# %%
a = 12
b = 23
c = 34
d = 45

a<b and b>c and c==d and d>c and b!=d #and condition
# Out:
# False

# %%
# or condition
a = [1,22,565]
b = 4567
c = 'ayush'
d = 'karan'

(a is b) or (c  < d) or (d>c) or (b==b)
# Out:
# True

# %%
# Bitwise opeartor
# bit zero 0 and 1

# %%
bin(12)
# Out:
# '0b1100'
