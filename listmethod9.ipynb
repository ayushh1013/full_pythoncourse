# %%
a = ['ayush','yash','kartik']
print(a)
# Out:
# ['ayush', 'yash', 'kartik']

# %%
#append
a.append('om')

# %%
a
# Out:
# ['ayush', 'yash', 'kartik', 'om']

# %%
a.append({"name": "Alice", "age": 30, "city": "New York"})

# %%
a
# Out:
# ['ayush',
#  'yash',
#  'kartik',
#  'om',
#  {'name': 'Alice', 'age': 30, 'city': 'New York'}]

# %%
#clear
b=  [123,4,455,44,3]
b.clear()

# %%
b
# Out:
# []

# %%
b.append((1,22,2,22,2,2,2,2))

# %%
b
# Out:
# [(1, 22, 2, 22, 2, 2, 2, 2)]

# %%
# copy
# shalllow and deep copy

# %%
ayush = [10000,9000]
om = ayush

# %%
ayush
# Out:
# [10000, 9000]

# %%
om
# Out:
# [10000, 9000]

# %%
#deep copy
ayush.append(1000000)

# %%
ayush
# Out:
# [10000, 9000, 1000000]

# %%
om
# Out:
# [10000, 9000, 1000000]

# %%
a = [1,2,2,23]
b = a.copy()

# %%
b
# Out:
# [1, 2, 2, 23]

# %%
#shallow cop
a = [12,1,22,33,3,344,2]

b = a.copy()

# %%
b.append(12243433)

# %%
b
# Out:
# [12, 1, 22, 33, 3, 344, 2, 12243433]

# %%
a
# Out:
# [12, 1, 22, 33, 3, 344, 2]

# %%
#shalllow copy :- withiut using copy method
# slicing

# %%
a = [2,1,243,25]
b = a[:]

# %%
print(b)
# Out:
# [2, 1, 243, 25]

# %%
b.append(765274557247)

# %%
b
# Out:
# [2, 1, 243, 25, 765274557247]

# %%
a.append(72376)

# %%
a
# Out:
# [2, 1, 243, 25, 72376]

# %%
a[::1]
# Out:
# [2, 1, 243, 25, 72376]

# %%
#count
a = [23,33,443,34,5,3,2,2,2,22]

# %%
a.count(2)
# Out:
# 3

# %%
#extend
a
a.extend([10,20,30])

# %%
a
# Out:
# [23, 33, 443, 34, 5, 3, 2, 2, 2, 22, 10, 20, 30]

# %%
a[5] = 1

# %%
a
# Out:
# [23, 33, 443, 34, 5, 1, 2, 2, 2, 22, 10, 20, 30]

# %%
a.index(443)
# Out:
# 2

# %%
a.index(5,1)
# Out:
# 4

# %%
a.index(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 a.index(100)
#
# ValueError: 100 is not in list

# %%
'34'+45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 '34'+45
#
# TypeError: can only concatenate str (not "int") to str

# %%
a.insert(0,'ayush')
print(drishti)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 a.insert(0,'ayush')
# ----> 2 print(drishti)
#
# NameError: name 'drishti' is not defined

# %%
#insert
a.insert(2,'ayush')
print('drishti')
# Out:
# drishti

# %%
print(a)
# Out:
# ['ayush', 'ayush', 'ayush', 'ayush', 'ayush', 'ayush', 23, 33, 443, 34, 5, 1, 2, 2, 2, 22, 10, 20, 30]

# %%
a.pop(2)
# Out:
# 'ayush'

# %%
print(a)
# Out:
# ['ayush', 'ayush', 'ayush', 23, 33, 443, 34, 5, 1, 2, 2, 2, 22, 10, 20, 30]

# %%
a.pop(1)
# Out:
# 'ayush'

# %%
print(a)
# Out:
# ['ayush', 'ayush', 33, 443, 34, 5, 1, 2, 2, 2, 22, 10, 20, 30]

# %%
#remove
a.remove(33)

# %%
print(a)
# Out:
# ['ayush', 'ayush', 443, 34, 5, 1, 2, 2, 2, 22, 10, 20, 30]

# %%
a.remove('ayush')

# %%
print(a)
# Out:
# ['ayush', 443, 34, 5, 1, 2, 2, 2, 22, 10, 20, 30]

# %%
a.remove('ayush')

# %%
print(a)
# Out:
# [443, 34, 5, 1, 2, 2, 2, 22, 10, 20, 30]

# %%
#reverse

# %%
a
# Out:
# [443, 34, 5, 1, 2, 2, 2, 22, 10, 20, 30]

# %%
a.reverse()

# %%
print(a)
# Out:
# [30, 20, 10, 22, 2, 2, 2, 1, 5, 34, 443]

# %%
a.sort(reverse = True)
print(a)
# Out:
# [443, 34, 30, 22, 20, 10, 5, 2, 2, 2, 1]
