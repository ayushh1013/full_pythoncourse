# %%
#oop -:
# conditional programming
# data types , if else,loops , op, break ,pass, continue

# functional programming:-
 #    def func
# 3 modules
# libraries class conceptt :- we will create our own data type
#class
# function bind class concept
##

# %%
# my class :- my datatype :- my class

# %%
b = 'ayush'

print(type(b))
# Out:
# <class 'str'>

# %%
b.upper()
# Out:
# 'AYUSH'

# %%
b.lower()
# Out:
# 'ayush'

# %%
# def techvidya

# %%
class Techvidya:
    def one():
        pass

    def two():
        pass

    def three():
        pass

# %%
my_var = Techvidya()
# class ke help se jb koi object banate hai toh usko instantiation process kehte hai

# %%
my_var.one()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 my_var.one()
#
# TypeError: Techvidya.one() takes 0 positional arguments but 1 was given

# %%
print(type(my_var))
# Out:
# <class '__main__.Techvidya'>

# %%
class Techvidya_final:
    def one(self):
        print(id(self))
        print('this is func one')

    def two(self):
        print('this is func two')

    def three(self):
        print('this is func three')

# %%
ob1 = Techvidya_final()

# %%
ob1.one()
# Out:
# 2202420646672
# this is func one

# %%
print(type(ob1))
# Out:
# <class '__main__.Techvidya_final'>

# %%
ob1.two()
# Out:
# this is func two

# %%
print(id(ob1))
# Out:
# 2202420644752
