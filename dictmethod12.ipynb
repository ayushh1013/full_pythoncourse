# %% [markdown]
# # Dict methods

# %%
print(dir(dict))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
methods = ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__']

# %%
print(len(methods))
# Out:
# 27

# %%
data = {'name':['shiksha','ayush','drishti','ajay'],'age':[1,2,3,4],
        'Tech':{'Name':'Mohan'}}

# %%
data
# Out:
# {'name': ['shiksha', 'ayush', 'drishti', 'ajay'],
#  'age': [1, 2, 3, 4],
#  'Tech': {'Name': 'Mohan'}}

# %%
id(data)
# Out:
# 2219708633664

# %%
data.clear()#clear

# %%
data
# Out:
# {}

# %%
#deep copy
a = {'Bank':1200,'Bank2':2345}
a
# Out:
# {'Bank': 1200, 'Bank2': 2345}

# %%
b = a
#deep copy

# %%
b
# Out:
# {'Bank': 1200, 'Bank2': 2345}

# %%
b['Bank'] = 120000

# %%
a
# Out:
# {'Bank': 120000, 'Bank2': 2345}

# %%
#shallow copy
a = {'Locker1':123,'Locker2':900}
b = a.copy()

print(b)
# Out:
# {'Locker1': 123, 'Locker2': 900}

# %%
b['Locker1'] = 200000

# %%
b
# Out:
# {'Locker1': 200000, 'Locker2': 900}

# %%
a
# Out:
# {'Locker1': 123, 'Locker2': 900}

# %%
#get
a['Locker2'] = 900000

# %%
a
# Out:
# {'Locker1': 123, 'Locker2': 900000}

# %%
a.get('Locker1') ==123
# Out:
# True

# %%
a.get('Age')

# %%
a
# Out:
# {'Locker1': 123, 'Locker2': 900000}

# %%
#items
a.items()
# Out:
# dict_items([('Locker1', 123), ('Locker2', 900000)])

# %%
a
# Out:
# {'Locker1': 123, 'Locker2': 900000}

# %%
a.get('Locker2')
# Out:
# 900000

# %%
list(a.items())[1]
# Out:
# ('Locker2', 900000)

# %%
a.items()
# Out:
# dict_items([('Locker1', 123), ('Locker2', 900000)])

# %%
z = a.items()

# %%
b = list(z)

# %%
b[1]
# Out:
# ('Locker2', 900000)

# %%
b = {}

# %%
b = b.fromkeys(a)

# %%
b
# Out:
# {'Locker1': None, 'Locker2': None}

# %%
a.update([('bmw',12),('kia',23)])

# %%
a
# Out:
# {'Locker1': 123, 'Locker2': 900000, 'bmw': 12, 'kia': 23}

# %%
a.update(audi=12,jndjck=23)

# %%
a
# Out:
# {'Locker1': 123,
#  'Locker2': 900000,
#  'bmw': 12,
#  'kia': 23,
#  'audi': 12,
#  'jndjck': 23}
