# %%
# webscrapping :- get data from website


Limited time deal
₹43,999.00
M.R.P: ₹44,999.00
REDMI Note 15 Pro+ 5G (Coffee Mochaa, 12GB+512GB) | 200MasterPixel OIS Camera | Snapdragon 7s Gen 4 | 17.3cm CrystalRes AMOLED Screen | IP66/68/69/69K | Mega 6500mAh Si/C Battery | 100W Hyper ChargingREDMI Note 15 Pro+ 5G (Coffee Mochaa, 12GB+512GB) | 200…

Shop Redmi dealsShop Redmi deals
# Out:
#   Cell In[4], line 5
#     ₹43,999.00
#     ^
# SyntaxError: invalid character '₹' (U+20B9)

# %%
# api :- application programming interface  use karte hai data magana ke liye

# %%
# scrap data magna
# scarp :- api

# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
url = ''' https://phabricator.wikimedia.org/T400119'''

# %%
import requests as r

# %%
response = r.get(url)

# %%
html_code = response.content

# %%
print(html_code)
# Out:
# b'Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.\n'

# %%
from bs4 import BeautifulSoup

# %%
BeautifulSoup(html_code,'html.parser')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_14456\1551405256.py:1: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   BeautifulSoup(html_code,'html.parser')
# Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.

# %%
print(soup.pretify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(soup.pretify())
#
# NameError: name 'soup' is not defined
