# %%
a = (12,3232,322,32321,)
print(a,type(a))
# Out:
# (12, 3232, 322, 32321) <class 'tuple'>

# %%
b = 984309,900,9039,39
print(b,type(b))
# Out:
# (984309, 900, 9039, 39) <class 'tuple'>

# %%
#single element tuple
a = (23,)
print(a,type(a))
# Out:
# (23,) <class 'tuple'>

# %%
#basic operation
a = (1,2,3,4)
b = (3,4,5)
print(a*b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 a = (1,2,3,4)
#       3 b = (3,4,5)
# ----> 4 print(a*b)
#
# TypeError: can't multiply sequence by non-int of type 'tuple'

# %%
a = (1,2,3,4)
b = (3,4,5)
print(b*7)
# Out:
# (3, 4, 5, 3, 4, 5, 3, 4, 5, 3, 4, 5, 3, 4, 5, 3, 4, 5, 3, 4, 5)

# %%
#tuple are immutable in nature
#we can not change or assign item
# remains same as list
# indexing,slicing,nested,negative indexing

# %%
a = (1,23,34,34)

print(a[2])
# Out:
# 34

# %%
a[2] = 2332
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a[2] = 2332
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Basic func
a = (5558,778,8789,8989,6768)
a
# Out:
# (5558, 778, 8789, 8989, 6768)

# %%
min(a)
# Out:
# 778

# %%
sum(a)
# Out:
# 30882

# %%
id(a)
# Out:
# 2560951514784

# %%
len(a)
# Out:
# 5

# %%
# nested tuple

a  = (1,2,2,45,(3,3,4,56,(909,89)))
a
# Out:
# (1, 2, 2, 45, (3, 3, 4, 56, (909, 89)))

# %%
a[-1][3]
# Out:
# 56

# %%
a = list(a)
a[2] = 9999

print(a)

a = tuple(a)
a
# Out:
# [1, 2, 9999, 45, (3, 3, 4, 56, (909, 89))]
# (1, 2, 9999, 45, (3, 3, 4, 56, (909, 89)))

# %%
z = (575,[678678,554],55)
z
z[-1][-1] = 87
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 z = (575,[678678,554],55)
#       2 z
# ----> 3 z[-1][-1] = 87
#
# TypeError: 'int' object does not support item assignment

# %% [markdown]
# # methods

# %%
a = (4,5,6,6,3,3,4,3,3,4,7,9,0)
a.count(3)
# Out:
# 4

# %%
a.index(0)
# Out:
# 12

# %% [markdown]
# # Dictionary/Mapping/hash/JSON

# %%
a = {'name':'ayush'}

# %%
print(a)
# Out:
# {'name': 'ayush'}

# %%
# immutables:- tuples, str, int ,float, complex,bool, frozenset
# mutables:-list, set, dict

# %%
a = {'Name' : 'ayush','age':23,'Address': 'noida'}

# %%
a
# Out:
# {'Name': 'ayush', 'age': 23, 'Address': 'noida'}

# %%
len(a)
# Out:
# 3

# %%
b = {'Names':['Ayush','Drishti','OM','Kartik'],
     'salary':[3000000000,20000000,67868,8],
     'Age':[122,34,232,3131]}

# %%
b
# Out:
# {'Names': ['Ayush', 'Drishti', 'OM', 'Kartik'],
#  'salary': [3000000000, 20000000, 67868, 8],
#  'Age': [122, 34, 232, 3131]}

# %%
import pandas as pd

# %%
pd.DataFrame(b)
# Out:
#      Names      salary   Age
# 0    Ayush  3000000000   122
# 1  Drishti    20000000    34
# 2       OM       67868   232
# 3   Kartik           8  3131

# %%
table = pd.DataFrame(b)

# %%
table.to_excel('student_details.xlsx')

# %%
a = {43-3j:[1,233,546,7]}

print(a)
# Out:
# {(43-3j): [1, 233, 546, 7]}

# %%
#frozen set

# %%
c = frozenset({1,2,2,2})

# %%
c
# Out:
# frozenset({1, 2})

# %%
print(type(c))
# Out:
# <class 'frozenset'>
