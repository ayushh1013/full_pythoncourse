# %%
#relational operators :<>,==,!=,<=,>=
#identity op:- is , is not
#Logical op:- and,or , not

# %%
age = 6
if age >= 18:
    print('you can vote!!!')
else:
    print('you can not vote')
# Out:
# you can not vote

# %%
age = int(input('Enter your age'))
if age >= 18:
    print('you can vote bhg tere ma ka naka saki naka!!!')
else:
    print('you can not vote')
# Out:
# Enter your age 56
# you can vote bhg tere ma ka naka saki naka!!!

# %%
students = ['ayush','ravi','om','rahul','sumit']

new_students = input('Enter your name:')

if new_students in students:
    print('Your name already exist !!')

else:
    print(f'welcome {new_students}')
    students.append(new_students)
# Out:
# Enter your name: drishti
# welcome drishti

# %%
students
# Out:
# ['ayush', 'ravi', 'om', 'rahul', 'sumit', 'drishti']

# %%
user_id = input('create your user id: ')
password = input('crete your password!!')

name = input('Enter your name: ')
uid = input('Enter your user id:')
pwd = input('enter your password: ')

if (user_id == uid) and (password == pwd ):
    print(f'Welcome{name}\nHow are you??')
else:
    print('incorrect userid or password!!')
# Out:
# create your user id:  dqwqd
# crete your password!! dWd
# Enter your name:  DWd
# Enter your user id: WDWD
# enter your password:  wdwd
# incorrect userid or password!!

# %%
# multipleif condition

# %%
age = 12

name= 'ayush'

address = 'jabalpur'

if age >=10:
    print('yiu con vote')

if name == 'ayush':
    print('Welcome ayush')

if address == 'noida':
    print('you are in noida')

else:
    print('we are learning python')
# Out:
# yiu con vote
# Welcome ayush
# we are learning python

# %%
#if else ladder

# %%
n1=2384923075
n2=3243852745
n3=8098954940
n4 =909985487

if n1 >n2 and n1>n3 and n1>n4:
    print(f'{n1} greatest amongst LL NO')

elif n2 > n1 and n2>n3 and n3>n4:
    print(f'{n2} greatest amongst LL NO')

elif n3>n1 and n3>n3 and n3>n4:
    print(f'{n3} greatest amongst LL NO')
else:
    print(f'{n4} greatest amongst LL NO')
# Out:
# 909985487 greatest amongst LL NO

# %%
maths = 55
english = 65
sci = 51
hindi = 328787
sst = 38

if(maths>100 or maths<0) or(sci>100 or sci<0) or (sst>100 or sst<0) or (english>100 or english<0) or (hindi>100 or hindi<0) :
    print('invalid Marks')
total = maths + english + sci + hindi + sst

percentage = total/5

if percentage >=90:
    print(f'you have scored A+ with{percentage}%')

elif 80 <= percentage>=90:
    print(f'you have scored b+ with{percentage}%')
elif 70<=percentage<80:
    print(f'you have scored c+ with{percentage}%')

elif 60<= percentage<70:
    print(f'you have scored d+ with{percentage}%')

elif 50<= percentage<60:
    print(f'you have scored d+ with{percentage}%')

elif 40<= percentage<50:
    print(f'you have scored d+ 😊with{percentage}%')
# Out:
# invalid Marks
# you have scored A+ with65799.2%

# %%
word = input('enter word:').lower()
if word == word[:: -1]:
    print(f'{word} is palindrome')

else:
    print(f'{word} is not palindrome')
# Out:
# enter word: ayush
# ayush is not palindrome

# %%
print('yes') if a%b==0 else print('bhg teri maka')
# Out:
# yes

# %%
a = 879832479
b = 3

if a%b == 0:
    print(f'{a} is divisible by {b}')

else:
    print(f'{a} is not divisible by {b}')
# Out:
# 879832479 is divisible by 3

# %%
#even odd
b = 847291
print('even no') if b%2==0 else print('odd number')
# Out:
# odd number

# %%
# if else pass
if 0 in [1,2,3,4]:
    pass

else:
    print('yes')
# Out:
# yes

# %%
import random

# %%
# %pip install cowsay
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script cowsay.exe is installed in 'C:\Users\ASUS\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import cowsay

# %%
cowsay.meow('ayush')
# Out:
#   _____
# | ayush |
#   =====
#      \
#       \
#        \
#         \
#                        _ ___.--'''`--''//-,-_--_.
#            \\`"' ` || \\\\ \\ \\\\/ / // / ,-\\\\`,_
#           /'`  \\ \\ || Y  | \\|/ / // / - |__ `-,
#          /\@"\\  ` \\ `\\ |  | ||/ // | \\/  \\  `-._`-,_.,
#         /  _.-. `.-\\,___/\\ _/|_/_\\_\\/|_/ |     `-._._)
#         `-'``/  /  |  // \\__/\\__  /  \\__/ \\
#              `-'  /-\\/  | -|   \\__ \\   |-' |
#                __/\\ / _/ \\/ __,-'   ) ,' _|'
#               (((__/(((_.' ((___..-'((__,'

# %%
cowsay.cow('ayush')
# Out:
#   _____
# | ayush |
#   =====
#      \
#       \
#         ^__^
#         (oo)\_______
#         (__)\       )\/\
#             ||----w |
#             ||     ||

# %%
#cowsay.trek('ayush')

# %%
cowsay.miki('ayush')
# Out:
#   _____
# | ayush |
#   =====
#      \
#       \                  &************************&
#        \             &******************************&
#         \          &**********************************&
#                  &**************************************&
#                &*****************************************&
#               &*******************************************&
#              &*********************************************&
#             &***********************************************&
#            &************************************************&
#            &***#########********#########*******************&
#            &*##       ##########          ##################&
#            &*##   O   ##@**####   O       ##***************&
#            &***#########@*******#########*****************&
#            &***********@*********************************&
#            &**********@*********************************&
# ...

# %%
cowsay.dragon('ayush')
# Out:
#   _____
# | ayush |
#   =====
#        \
#         \
#          \
#           \
#                                 / \\  //\\
#                  |\\___/|      /   \\//  \\\\
#                  /0  0  \\__  /    //  | \\ \\
#                 /     /  \\/_/    //   |  \\  \\
#                 \@_^_\@'/   \\/_   //    |   \\   \\
#                 //_^_/     \\/_ //     |    \\    \\
#              ( //) |        \\///      |     \\     \\
#            ( / /) _|_ /   )  //       |      \\     _\\
#          ( // /) '/,_ _ _/  ( ; -.    |    _ _\\.-~        .-~~~^-.
#        (( / / )) ,-{        _      `-.|.-~-.           .~         `.
#       (( // / ))  '/\\      /                 ~-. _ .-~      .-~^-.  \\
#       (( /// ))      `.   {            }                   /      \\  \\
#        (( / ))     .----~-.\\        \\-'                 .~         \\  `. \\^-.
#                   ///.----..>        \\             _ -~             `.  ^-`  ^-_
# ...

# %%
cowsay.daemon('ayush')
# Out:
#   _____
# | ayush |
#   =====
#              \
#               \
#                \
#                 \
#                  /- _  `-/  '
#                 (/\/ \ \   /\
#                 / /   | `    \
#                 O O   ) /    |
#                 `-^--'`<     '
#                (_.)  _  )   /
#                 `.___/`    /
#                   `-----' /
#      <----.     __ / __   \
#      <----|====O)))==) \) /====
#      <----'    `--' `.__,' \
#                   |        |
#                    \       /
#              ______( (_  / \______
#            ,'  ,-----'   |        \
#            `--{__________)        \/

# %%
random.randint(1111,9999)
# Out:
# 2623

# %%
import random

# Choices
choices = ["rock", "paper", "scissors"]

# Get user input
user_choice = input("Enter your choice (rock, paper, scissors): ").lower()

# Get computer choice
computer_choice = random.choice(choices)

print(f"\nYou chose: {user_choice}")
print(f"Computer chose: {computer_choice}\n")

# Compare choices
if user_choice == computer_choice:
    print("It's a tie!")
elif user_choice == "rock":
    if computer_choice == "scissors":
        print("You win! Rock crushes scissors.")
    else:
        print("You lose! Paper covers rock.")
elif user_choice == "paper":
    if computer_choice == "rock":
        print("You win! Paper covers rock.")
    else:
        print("You lose! Scissors cut paper.")
elif user_choice == "scissors":
    if computer_choice == "paper":
        print("You win! Scissors cut paper.")
    else:
        print("You lose! Rock crushes scissors.")
else:
    print("Invalid input! Please choose rock, paper, or scissors.")
# Out:
# Enter your choice (rock, paper, scissors):  scissor
# You chose: scissor
# Computer chose: rock
#
# Invalid input! Please choose rock, paper, or scissors.
