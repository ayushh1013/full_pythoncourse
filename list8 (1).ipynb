# %%
a = 'This is a baby and his name is ayush'
a.rpartition('a')
# Out:
# ('This is a baby and his name is ', 'a', 'yush')

# %%
a.find('u',33)
# Out:
# 33

# %%
a[:33]
# Out:
# 'This is a baby and his name is ay'

# %% [markdown]
# ## List

# %%
a = ['frfmklrjflk',77686]
print(type(a))
# Out:
# <class 'list'>

# %%
#hetrogeneous
a = ['ayush',23,(6237,6738),{12,2,23},[73871,82179]]
print(a)
# Out:
# ['ayush', 23, (6237, 6738), {2, 12, 23}, [73871, 82179]]

# %%
# list and basic operation
a = [12,121,22]
b = [3,45,4,5]
print(a+b)
# Out:
# [12, 121, 22, 3, 45, 4, 5]

# %%
a = [12,121,22]
print(a*4)
# Out:
# [12, 121, 22, 12, 121, 22, 12, 121, 22, 12, 121, 22]

# %%
a = ([1,2,2,3,3,44])
print(a,type(a))
# Out:
# [1, 2, 2, 3, 3, 44] <class 'list'>

# %%
#2 list support slicing

# %%
a = [1,23,44,55,667]
a[2:4]
# Out:
# [44, 55]

# %%
a[::2]
# Out:
# [1, 44, 667]

# %%
a[-3] == a[1]
# Out:
# False

# %%
a[2] = 'aayuhs'

# %%
a
# Out:
# ['ayush', 23, 'aayuhs', {2, 12, 23}, [73871, 82179]]

# %%
var_a = [1,23,25,6,[2,43,433]]
var_a[-1]
# Out:
# [2, 43, 433]

# %%
var_a
# Out:
# [1, 23, 25, 6, [2, 43, 433]]

# %%
var_a[-1][1]
# Out:
# 43

# %%
a = [1,243,25,[1,243,46,[12,[2,3,45,6],6]]]
a
# Out:
# [1, 243, 25, [1, 243, 46, [12, [2, 3, 45, 6], 6]]]

# %%
a[3]
# Out:
# [1, 243, 46, [12, [2, 3, 45, 6], 6]]

# %%
a[-1]
# Out:
# [1, 243, 46, [12, [2, 3, 45, 6], 6]]

# %%
a[3][3]
# Out:
# [12, [2, 3, 45, 6], 6]

# %%
a[3][3][1][1] = 5

# %%
a
# Out:
# [1, 243, 25, [1, 243, 46, [12, [2, 5, 45, 6], 6]]]

# %%
a = [1,2,3]
True in a
# Out:
# True

# %%
a = [12,77.78]
True in a
# Out:
# False
