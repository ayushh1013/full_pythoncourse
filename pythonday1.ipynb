# %% [markdown]
# ### Data Types

# %%
# list
a = [12,3,4,54,32,'ayuyuush',34,55]
print(a)
# Out:
# [12, 3, 4, 54, 32, 'ayuyuush', 34, 55]

# %%
#set unorderd

a = {1,1,2,2,3,4,5,6}
a
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(type(a))
# Out:
# <class 'set'>

# %% [markdown]
# ![https___dev-to-uploads.s3.amazonaws.com_uploads_articles_kkq35gojs94jh9gpju2d.webp](attachment:31005e99-5db1-4fbe-b4ff-021d5d773d77.webp)

# %%
#467='dfef'

# %%
a_v_3 = 1233

# %%
#python is case sensitive lang
name = 'ayush'
Name = 'Drishti'

# %%
print(name)
# Out:
# ayush

# %%
id(name)
# Out:
# 2491234768608

# %%
id(Name)
# Out:
# 2491234770096

# %%
roll = 12

# %%
roll =79

# %%
print(roll)
# Out:
# 79

# %% [markdown]
# # operator

# %%
# Arithmetic oper

# %%
a =556
b = 56
print(a-b)
# Out:
# 500

# %%
a =50
b = 56
print(a**b)
# Out:
# 138777878078144567552953958511352539062500000000000000000000000000000000000000000000000000000000

# %%
print(12**10)
# Out:
# 61917364224

# %%
# modulus

# %%
23/2
# Out:
# 11.5

# %%
23%5
# Out:
# 3

# %%
24%5
# Out:
# 4

# %%
print(23//3)
print('Floor Div!!') #not given floor div
# Out:
# 7
# Floor Div!!
