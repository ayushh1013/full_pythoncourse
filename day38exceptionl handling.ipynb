# %%
import request  r
# Out:
#   Cell In[1], line 1
#     import request r
#                    ^
# SyntaxError: invalid syntax

# %%
k = kaka
k.append()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 k = kaka
#       2 k.append()
#
# NameError: name 'kaka' is not defined

# %%
k = 'ewf'
k.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 k = 'ewf'
# ----> 2 k.append()
#
# AttributeError: 'str' object has no attribute 'append'

# %%
d = [123,324,31]
d[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 d = [123,324,31]
# ----> 2 d[12]
#
# IndexError: list index out of range

# %%
if 2==22:
print('klekfe')
# Out:
#   Cell In[8], line 2
#     print('klekfe')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
import requestss as r
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import requestss as r
#
# ModuleNotFoundError: No module named 'requestss'

# %%
from math import pii
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from math import pii
#
# ImportError: cannot import name 'pii' from 'math' (unknown location)

# %%
print(324/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(324/0)
#
# ZeroDivisionError: division by zero

# %%
deff = int(input('enter a number'))
print(deff)
# Out:
# enter a number r
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 deff = int(input('enter a number'))
#       2 print(deff)
#
# ValueError: invalid literal for int() with base 10: 'r'

# %%
def abc():
    abc()

# %%
abc()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 abc()
#
# Cell In[17], line 2, in abc()
#       1 def abc():
# ----> 2     abc()
#
# Cell In[17], line 2, in abc()
#       1 def abc():
# ----> 2     abc()
#
#     [... skipping similar frames: abc at line 2 (2974 times)]
#
# Cell In[17], line 2, in abc()
#       1 def abc():
# ----> 2     abc()
#
# RecursionError: maximum recursion depth exceeded

# %%
open('ezera')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 open('ezera')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ezera'

# %%
print('asuh')
print('efdas')


try:
   
    
    print(1/0)

except:
    pass
    
    print('python\n'*5)
    
    for i in range(5):
        print(i)
# Out:
# asuh
# efdas
# python
# python
# python
# python
# python
#
# 0
# 1
# 2
# 3
# 4

# %%
try :
    a = [1,2,3,3,3,3]
    print('element is :',a[1])
    data = {'class':3, 'age':23}

    print(data['rfew'])

except Exception as e :
    print('wrong',e)

else :
    print('ewfrewfewf')

finally:
    print('efvuivhiesolfu')
# Out:
# element is : 2
# wrong 'rfew'
# efvuivhiesolfu

# %%
try:
    print('svhjkfdhvlkhfvdlhkvfdkh')

finally:
    print('jdfjsdhkfh')
# Out:
# svhjkfdhvlkhfvdlhkvfdkh
# jdfjsdhkfh

# %%
#concept try with specific error

# %%
age = 17

if age >=18:
    print('gkutgukj')

else:
    raise Exception('ryfyjtf')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4     print('gkutgukj')
#       6 else:
# ----> 7     raise Exception('ryfyjtf')
#
# Exception: ryfyjtf

# %%
pwd = 1232

try:
    if pwd == 1111:
        print('succ3es')
    else:
        raise ayhudjvfijvkj('efeaf')

except Exception as e:
    print(e)
print('wlcome')
# Out:
# name 'ayhudjvfijvkj' is not defined
# wlcome

# %%
class my_error(Exception):
    pass

# %%
pwd = 11110

if pwd == 111:
    print('success')
else:
    raise my_error('uhu')
print('welcome')
# Out:
# ---------------------------------------------------------------------------
# my_error                                  Traceback (most recent call last)
# Cell In[12], line 6
#       4     print('success')
#       5 else:
# ----> 6     raise my_error('uhu')
#       7 print('welcome')
#
# my_error: uhu

# %%
import requests as r

# %%
try:
    


    
    url = '''https://pkimges.sortd.pro/englishkesari2025-04-24/9xu3hxt7/Sachin-tendulkar-45.jpg'''
    
    response = r.get(url)
    data = response.content
    if len(data)>0:
      with open('t20_.jpg','wb') as f:
         f.write(data)

    else:
        raise Exception('error with')

except Exception as e:
    print('spmething went wrong',e)

else:
    print('image download successfully')
    display(IPython.display.Image('t20_.jpg',width=100,height=100))
# Out:
# spmething went wrong HTTPSConnectionPool(host='pkimges.sortd.pro', port=443): Max retries exceeded with url: /englishkesari2025-04-24/9xu3hxt7/Sachin-tendulkar-45.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001FC290363F0>: Failed to resolve 'pkimges.sortd.pro' ([Errno 11001] getaddrinfo failed)"))

# %%
import  IPython

# %%
 display(IPython.display.Image('t20_.jpg',width=100,height=100))
